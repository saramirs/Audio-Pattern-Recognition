# %%
import json
import os
import math
import librosa
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
DATASET_PATH = "/content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original"
JSON_PATH = "/content/drive/MyDrive/AudioPatternRecognition/Final_Project/Data_kmeans.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30  # measured in seconds (Each track in our dataset is 30 seconds)
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION
NUM_CLUSTERS = 10  # Number of clusters for K-Means (Default 10 for GTZAN)

def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along with genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into. => To increase the number of training tracks.
        :return:
    """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],  #for example: list:["classical","blues",...] => classical is mappied to 0 and blues to 1. => each genre is mapped to its coresponding index in the list.
        "labels": [], #These are the outputs => is a list : [0, 1, 0] => it is coresponding results to the below list of MFCCs => it says that the first list of MFCCs is classical.
        "mfcc": []  #These are the inputs => is a list : [[...], [...], [...], ... ]
        "clusters": []  # Stores cluster labels assigned by K-Means
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)  # ceil function: round the number to its higher integer: (1.2 => 2)

    all_mfccs = []  # Collect all MFCCs before clustering
    all_labels = []  # Store actual genre labels

    # **********At the end of this "for" loop, we are gonna have all the ganres ("mapping" variable), also the MFCCs for each segment, and the labels for each segments.
    # loop through all genre sub-folder => At each iteration of i, we are in different genre =>but=> the first iteration is for dataset_path
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):  #dirpath: current folder / dirnames: all the subfolders in current folder / filenames: all the files in current folder

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

                # 1. load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # 2. process all segments of audio file
                for d in range(num_segments):

                    # 2.1. calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # 2.2. extract mfcc *********************** #we process a slice of the signal between (start sample< <finish sample)
                    mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T  # Transpose to have time-steps as rows

                    #2.3. store only mfcc feature with expected number of vectors (As some tracks may not be exactly 30 seconds => the last segment may be shorter => but we need the ones with the exact segment size.)
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        all_mfccs.append(mfcc.flatten())  # Store MFCCs for clustering
                        all_labels.append(i - 1)  # Store actual genre label
                        print("{}, segment:{}".format(file_path, d + 1))

    # Convert MFCCs to NumPy array for clustering
    all_mfccs = np.array(all_mfccs)

    # Apply K-Means clustering
    print("\nApplying K-Means Clustering...")
    kmeans = KMeans(n_clusters=NUM_CLUSTERS, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(all_mfccs)  #The MFCC features (extracted from each segment) are clustered, and the corresponding cluster label is assigned to each segment.

    # Store clustered MFCCs in JSON
    for i, mfcc in enumerate(all_mfccs):
        data["mfcc"].append(mfcc.tolist())  # Save MFCC data
        data["labels"].append(all_labels[i])  # Save actual genre label
        data["clusters"].append(int(cluster_labels[i]))  # Save K-Means cluster label

    # save data to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

    print("\nMFCC extraction and K-Means clustering completed. Data saved to:", json_path)

# %%
if __name__ == "__main__":
  save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00005.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00005.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00005.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00005.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00005.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00005.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00005.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00005.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00004.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00002.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00001.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00000.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00003.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00015.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00007.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00010.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00008.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00018.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00017.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00014.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00006.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00009.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00013.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00011.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00016.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00012.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00031.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00029.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00024.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00022.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00019.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00021.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00020.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00025.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00026.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00028.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00030.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00027.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00023.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00043.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00036.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00038.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00040.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00033.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00035.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00034.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00039.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00042.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00037.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00037.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00037.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00037.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/jazz/jazz.00037.wav, segment:5
# ...
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00074.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00074.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00074.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00074.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00074.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00074.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00079.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00089.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00088.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00094.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00090.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00095.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00096.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00091.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00098.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00092.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00097.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00099.wav, segment:10
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:1
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:2
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:3
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:4
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:5
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:6
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:7
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:8
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:9
# /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Dataset/genres_original/rock/rock.00093.wav, segment:10
#
# Applying K-Means Clustering...
#
# MFCC extraction and K-Means clustering completed. Data saved to: /content/drive/MyDrive/AudioPatternRecognition/Final_Project/Data_kmeans.json

# %%
import numpy as np
import json
from collections import Counter

# Analyze the purity of clusters based on genre labels.

# Load the JSON data
JSON_PATH = "/content/drive/MyDrive/AudioPatternRecognition/Final_Project/Data_kmeans.json"

with open(JSON_PATH, "r") as fp:
    data = json.load(fp)

# Extract labels and cluster assignments
labels = np.array(data["labels"])  # Actual genre labels
clusters = np.array(data["clusters"])  # Clustered labels

# Analyze purity of each cluster
cluster_purity = {}
num_clusters = len(set(clusters))  # Get the number of unique clusters

for cluster_id in range(num_clusters):
    indices = np.where(clusters == cluster_id)[0]  # Get indices of samples in this cluster
    genre_counts = Counter(labels[indices])  # Count genre occurrences
    dominant_genre = genre_counts.most_common(1)[0]  # Get most common genre in the cluster
    purity = dominant_genre[1] / len(indices)  # Compute purity score

    cluster_purity[cluster_id] = {
        "Dominant Genre": data["mapping"][dominant_genre[0]],
        "Purity Score": purity,
        "Genre Distribution": genre_counts
    }

# Print results
for cluster_id, info in cluster_purity.items():
    print(f"Cluster {cluster_id}:")
    print(f"  - Dominant Genre: {info['Dominant Genre']}")
    print(f"  - Purity Score: {info['Purity Score']:.2f}")
    print(f"  - Genre Distribution: {info['Genre Distribution']}\n")
# Out:
# Cluster 0:
#   - Dominant Genre: metal
#   - Purity Score: 0.24
#   - Genre Distribution: Counter({6: 451, 9: 315, 0: 292, 3: 292, 4: 242, 2: 186, 8: 48, 1: 41, 5: 22, 7: 3})
#
# Cluster 1:
#   - Dominant Genre: classical
#   - Purity Score: 0.35
#   - Genre Distribution: Counter({1: 269, 5: 200, 0: 130, 2: 62, 8: 49, 9: 23, 7: 12, 4: 11, 3: 8, 6: 1})
#
# Cluster 2:
#   - Dominant Genre: reggae
#   - Purity Score: 0.22
#   - Genre Distribution: Counter({8: 313, 2: 229, 9: 181, 3: 151, 0: 149, 5: 138, 4: 122, 6: 47, 1: 41, 7: 34})
#
# Cluster 3:
#   - Dominant Genre: pop
#   - Purity Score: 0.43
#   - Genre Distribution: Counter({7: 649, 3: 303, 4: 175, 9: 152, 2: 100, 5: 52, 8: 52, 6: 11, 1: 3})
#
# Cluster 4:
#   - Dominant Genre: classical
#   - Purity Score: 0.70
#   - Genre Distribution: Counter({1: 278, 5: 58, 0: 28, 2: 19, 8: 7, 9: 3, 4: 2, 7: 2, 3: 1})
#
# Cluster 5:
#   - Dominant Genre: jazz
#   - Purity Score: 0.27
#   - Genre Distribution: Counter({5: 205, 1: 183, 2: 143, 0: 131, 8: 43, 9: 26, 4: 12, 3: 7, 7: 3, 6: 2})
#
# Cluster 6:
#   - Dominant Genre: classical
#   - Purity Score: 0.92
#   - Genre Distribution: Counter({1: 160, 5: 9, 4: 2, 2: 1, 9: 1})
#
# Cluster 7:
#   - Dominant Genre: reggae
#   - Purity Score: 0.25
#   - Genre Distribution: Counter({8: 231, 5: 198, 0: 154, 9: 91, 2: 79, 4: 48, 3: 43, 7: 41, 6: 20, 1: 16})
#
# Cluster 8:
#   - Dominant Genre: metal
#   - Purity Score: 0.51
#   - Genre Distribution: Counter({6: 445, 0: 116, 9: 108, 4: 86, 3: 67, 2: 36, 8: 6, 1: 1})
#
# Cluster 9:
#   - Dominant Genre: hiphop
#   - Purity Score: 0.23
#   - Genre Distribution: Counter({4: 299, 7: 256, 8: 251, 2: 144, 3: 127, 5: 108, 9: 100, 6: 23, 1: 7})

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
from sklearn.manifold import TSNE

# t-SNE Visualization of MFCC Clusters

# Load the JSON data
JSON_PATH = "/content/drive/MyDrive/AudioPatternRecognition/Final_Project/Data_kmeans.json"

# Load the JSON data
with open(JSON_PATH, "r") as fp:
    data = json.load(fp)

# Extract MFCC features and cluster labels
mfccs = np.array(data["mfcc"])  # MFCC features
clusters = np.array(data["clusters"])  # Cluster labels

# Reduce MFCC dimensionality to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
mfcc_2d = tsne.fit_transform(mfccs)

# Plot the clusters
plt.figure(figsize=(10, 6))
scatter = plt.scatter(mfcc_2d[:, 0], mfcc_2d[:, 1], c=clusters, cmap="tab10", alpha=0.7)
plt.colorbar(scatter, label="Cluster ID")
plt.title("t-SNE Visualization of MFCC Clusters")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.show()
